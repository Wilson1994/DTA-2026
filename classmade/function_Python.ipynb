# %% [markdown]
# <a href="https://colab.research.google.com/github/Wilson1994/DTA-2026/blob/main/classmade/function_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function Python
# ```
# def name_func():
#   pass
# ```
